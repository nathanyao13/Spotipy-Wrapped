# %% [markdown]
# # EDA and User Generation

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ## Music Metadata

# %%
df = pd.read_csv("metadata.csv", header = 0)

# %%
df.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %%
df.shape
# Out:
# (1204025, 24)

# %% [markdown]
# ## User Generation

# %%
def generate_user_item(song_df, num_users=500, min_tracks=10, max_tracks=50, max_plays=20):
    user_item_data = []
    track_ids = song_df['id'].dropna().unique()

    for user_index in range(1, num_users + 1):
        user_id = user_index
        n_tracks = random.randint(min_tracks, max_tracks)
        listened_tracks = np.random.choice(track_ids, size=n_tracks, replace=False)

        for track_id in listened_tracks:
            play_count = random.randint(1, max_plays)
            user_item_data.append({
                'user_id': user_id,
                'track_id': track_id,
                'play_count': play_count
            })

    return pd.DataFrame(user_item_data)

# %%
user_item_df = generate_user_item(df, num_users=1000)

user_item_df.to_csv("user_item.csv", index=False)

# %%
user_item_df.head()
# Out:
#    user_id                track_id  play_count
# 0        1  0vcV9S5LPMcAQZuxmvc8sE          14
# 1        1  1g5ZSaN2JBegmWwvKAEawZ           4
# 2        1  0MbIWHZ5ojkbWHfgKjrx23          20
# 3        1  3mXol3KLx3Q1RxVNLE1OJa           4
# 4        1  1K3OAJ09NrsXv4DCsPlYvQ           8
